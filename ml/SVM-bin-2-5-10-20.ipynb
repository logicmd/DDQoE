# %%
'''
Platform:  
{ 
     iPad: 10264251 
     Android: 7512890 
     iPhone: 5377486 
     Apple TV: 368609 
     iPod: 243399 
     Mac: 21074 
     Windows: 423 
     None: 133 
}

[1, 2, 3, 4, 5, 6, 7, 8],
['Apple TV', 'Mac', 'Windows', 'iPad', 'Android', 'iPhone', 'iPod', 'Unknown']
'''
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import cross_val_score
from sklearn.datasets import load_svmlight_file
from sklearn.cross_validation import train_test_split, KFold


from sklearn import svm

platform = { 
                   'All': -1,
                   'Apple TV': 1, 
                   'Mac': 2, 
                   'Windows': 3, 
                   'iPad': 4, 
                   'Android': 5, 
                   'iPhone': 6, 
                   'iPod' : 7, 
                   'None' :8, 
                }

metric_list = ['Watching Lasting Time(s)',
               'Ad Ratio',
               'Avg Bitrate(kbps)',
               'Switch(per hour)',
               'Initial Time(\'o clock)']

metric = {
                  'Watching Lasting Time(s)': 0,
                  'Ad Ratio': 1,
                  'Avg Bitrate(kbps)': 2,
                  'Switch(per hour)': 3,
                  'Initial Time(\'o clock)': 5
              }
train = None

bins = {
            'iPad': {
                'Watching Lasting Time(s)': [0, 4005.0, 300000],
                'Ad Ratio': [0, 0.89000000000000001, 1.1],
                'Avg Bitrate(kbps)': [0, 2125.0, 2500],
                'Switch(per hour)': [0, 0.10000000000000001, 61],
                'Initial Time(\'o clock)': [0, 16.18, 24]
            },
            'Android': {
                'Watching Lasting Time(s)': [0, 3675.0, 300000.0],
                'Ad Ratio': [0, 0.45, 1.1],
                'Avg Bitrate(kbps)': [0, 785.39999999999998, 2500],
                'Switch(per hour)': [0, 0.04, 50],
                'Initial Time(\'o clock)': [0, 15.57, 24]
            },
            'iPhone': {
                'Watching Lasting Time(s)': [0, 2378.0, 300000.0],
                'Ad Ratio': [0, 0.88, 1.1],
                'Avg Bitrate(kbps)': [0, 780.7, 2500],
                'Switch(per hour)': [0, 0.07, 61],
                'Initial Time(\'o clock)': [0, 16.02, 24]
            },
            'Apple TV': {
                'Watching Lasting Time(s)': [0, 6166, 300000.0],
                'Ad Ratio': [0, 0.86, 1.1],
                'Avg Bitrate(kbps)': [0, 1963, 2500],
                'Switch(per hour)': [0, 0.088, 50],
                'Initial Time(\'o clock)': [0, 16.05, 24]
            },
            
        }
        

class dt:

    def __init__(self):
        global train
        
        X_train, y_train = load_svmlight_file('./data/time_train4')
        X_train, y_train2 = load_svmlight_file('./data/ad_train4')
        X_train = X_train.toarray()
        train = np.column_stack((y_train, y_train2, X_train))



    def train_and_test(self, feature, label, n=10, test_size=0.1):
        scores = []
        max_score = -1
        max_clf = None
        
        kf = KFold(n=label.shape[0], n_folds=5)
        for train_index, test_index in kf:
            feature_train, feature_test = feature[train_index], feature[test_index]
            label_train, label_test = label[train_index], label[test_index]

            clf = svm.LinearSVC()
            clf = clf.fit(feature_train, label_train)
            score = clf.score(feature_test, label_test)
            if score > max_score:
                max_score = score
                max_clf = clf
            scores.append(score)
        print "Average scores: " + str(np.average(scores))
        return max_score, max_clf
            
    def plot(self, p):
        global platform
        global metric
        global train
        
        if platform[p] == platform['All']:
            mat = np.zeros((train[:,:].shape[0],5))
        else:
            mat = np.zeros((train[train[:,4]==platform[p],:].shape[0],5))
        for idx, m in enumerate(metric_list):

            if platform[p] == platform['All']:
                mat[:, idx] = numpy.digitize(train[:, metric[m]], bins['iPad'][m])
            else:
                mat[:, idx] = numpy.digitize(train[train[:,4]==platform[p], metric[m]], bins[p][m])
            
            #print "%f\t%f" %(np.amax(train[train[:,4]==platform[p], metric[m]]), np.amax(mat[:, idx]))
            
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        print 'Sample size: ' + str(mat.shape[0])
        
        time_train = mat[:, 0]
        ad_train = mat[:, 1]
        features = mat[:, 2:5]
        
        print p + ": time"
        time_score, time_clf = self.train_and_test(features, time_train)
        print "Best scores:" + str(time_score)
        print "Coef:" + str(time_clf.coef_) + ", Intercept:" + str(time_clf.intercept_)
        
        print p + ": ad"
        ad_score, ad_clf = self.train_and_test(features, ad_train)
        print "Best scores:" + str(ad_score)
        print "Coef:" + str(ad_clf.coef_) + ", Intercept:" + str(ad_clf.intercept_)
        

        
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        

if __name__ == '__main__':

    c = dt()
    
    c.plot('All')
    
    c.plot('iPad')
    
    c.plot('Android')
    
    c.plot('iPhone')
    
    c.plot('Apple TV')
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 55478
# All: time
# Average scores: 0.621129047718
# Best scores:0.6252703677
# Coef:[[-0.04711586 -0.4914441  -0.16105532]], Intercept:[ 0.92577101]
# All: ad
# Average scores: 0.645571282036
# Best scores:0.648039657503
# Coef:[[ 0.47517518  0.07497943 -0.01525581]], Intercept:[-0.90038954]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 23415
# iPad: time
# Average scores: 0.637753576767
# Best scores:0.643177450352
# Coef:[[-0.39347512 -0.67638006 -0.16789046]], Intercept:[ 1.86138557]
# iPad: ad
# Average scores: 0.568737988469
# Best scores:0.577194106342
# Coef:[[ 0.30098351  0.09534965 -0.05889496]], Intercept:[-0.47726508]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 13760
# Android: time
# Average scores: 0.553924418605
# Best scores:0.58648255814
# Coef:[[-0.44317199 -0.32238016 -0.11781969]], Intercept:[ 1.32053346]
# Android: ad
# Average scores: 0.548110465116
# Best scores:0.558502906977
# Coef:[[ 0.05911491  0.00722252 -0.18290667]], Intercept:[ 0.17175117]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 17102
# iPhone: time
# Average scores: 0.618231750574
# Best scores:0.62320958784
# Coef:[[-0.45240911 -0.665287   -0.09499314]], Intercept:[ 1.81527747]
# iPhone: ad
# Average scores: 0.561981209967
# Best scores:0.56783625731
# Coef:[[ 0.28726428  0.0989997  -0.01350814]], Intercept:[-0.50603062]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 348
# Apple TV: time
# Average scores: 0.59751552795
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-126cb9fc4716> in <module>()
#     170     c.plot('iPhone')
#     171
# --> 172     c.plot('Apple TV')
#
# <ipython-input-2-126cb9fc4716> in plot(self, p)
#     148
#     149         print p + ": ad"
# --> 150         ad_score, ad_clf = self.train_and_test(features, ad_train)
#     151         print "Best scores:" + str(ad_score)
#     152         print "Coef:" + str(ad_clf.coef_) + ", Intercept:" + str(ad_clf.intercept_)
#
# <ipython-input-2-126cb9fc4716> in train_and_test(self, feature, label, n, test_size)
#     107
#     108             clf = svm.LinearSVC()
# --> 109             clf = clf.fit(feature_train, label_train)
#     110             score = clf.score(feature_test, label_test)
#     111             if score > max_score:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     671         y_ind = self._enc.fit_transform(y)
#     672         if len(self.classes_) < 2:
# --> 673             raise ValueError("The number of classes has to be greater than"
#     674                              " one.")
#     675
#
# ValueError: The number of classes has to be greater than one.
# Best scores:0.628571428571
# Coef:[[ 0.25824452 -0.47201447 -0.17090126]], Intercept:[ 0.59535685]
# Apple TV: ad

# %%
'''
Platform:  
{ 
     iPad: 10264251 
     Android: 7512890 
     iPhone: 5377486 
     Apple TV: 368609 
     iPod: 243399 
     Mac: 21074 
     Windows: 423 
     None: 133 
}

[1, 2, 3, 4, 5, 6, 7, 8],
['Apple TV', 'Mac', 'Windows', 'iPad', 'Android', 'iPhone', 'iPod', 'Unknown']
'''
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import cross_val_score
from sklearn.datasets import load_svmlight_file
from sklearn.cross_validation import train_test_split, KFold


from sklearn import svm

platform = { 
                   'All': -1,
                   'Apple TV': 1, 
                   'Mac': 2, 
                   'Windows': 3, 
                   'iPad': 4, 
                   'Android': 5, 
                   'iPhone': 6, 
                   'iPod' : 7, 
                   'None' :8, 
                }

metric_list = ['Watching Lasting Time(s)',
               'Ad Ratio',
               'Avg Bitrate(kbps)',
               'Switch(per hour)',
               'Initial Time(\'o clock)']

metric = {
                  'Watching Lasting Time(s)': 0,
                  'Ad Ratio': 1,
                  'Avg Bitrate(kbps)': 2,
                  'Switch(per hour)': 3,
                  'Initial Time(\'o clock)': 5
              }
train = None

bins = {
            'All': {
                'Watching Lasting Time(s)': [0, 3306.0, 300000.0],
                'Ad Ratio': [0, 0.75, 1.1],
                'Avg Bitrate(kbps)': [0, 800, 2500],
                'Switch(per hour)': [0, 0.70, 61],
                'Initial Time(\'o clock)': [0, 16.05, 24]
            },
}
        

class dt:

    def __init__(self):
        global train
        
        X_train, y_train = load_svmlight_file('./data/time_train4')
        X_train, y_train2 = load_svmlight_file('./data/ad_train4')
        X_train = X_train.toarray()
        train = np.column_stack((y_train, y_train2, X_train))



    def train_and_test(self, feature, label, n=10, test_size=0.1):
        scores = []
        max_score = -1
        max_clf = None
        
        kf = KFold(n=label.shape[0], n_folds=5)
        for train_index, test_index in kf:
            feature_train, feature_test = feature[train_index], feature[test_index]
            label_train, label_test = label[train_index], label[test_index]

            clf = svm.LinearSVC()
            clf = clf.fit(feature_train, label_train)
            score = clf.score(feature_test, label_test)
            if score > max_score:
                max_score = score
                max_clf = clf
            scores.append(score)
        print "Average scores: " + str(np.average(scores))
        return max_score, max_clf
            
    def plot(self, p):
        global platform
        global metric
        global train
        
        if platform[p] == platform['All']:
            mat = np.zeros((train[:,:].shape[0],5))
        else:
            mat = np.zeros((train[train[:,4]==platform[p],:].shape[0],5))
        for idx, m in enumerate(metric_list):

            if platform[p] == platform['All']:
                mat[:, idx] = numpy.digitize(train[:, metric[m]], bins['All'][m])
            else:
                mat[:, idx] = numpy.digitize(train[train[:,4]==platform[p], metric[m]], bins[p][m])
            
            #print "%f\t%f" %(np.amax(train[train[:,4]==platform[p], metric[m]]), np.amax(mat[:, idx]))
            
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        print 'Sample size: ' + str(mat.shape[0])
        
        time_train = mat[:, 0]
        ad_train = mat[:, 1]
        features = mat[:, 2:5]
        
        print p + ": time"
        time_score, time_clf = self.train_and_test(features, time_train)
        print "Best scores:" + str(time_score)
        print "Coef:" + str(time_clf.coef_) + ", Intercept:" + str(time_clf.intercept_)
        
        print p + ": ad"
        ad_score, ad_clf = self.train_and_test(features, ad_train)
        print "Best scores:" + str(ad_score)
        print "Coef:" + str(ad_clf.coef_) + ", Intercept:" + str(ad_clf.intercept_)
        

        
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        

if __name__ == '__main__':
    c = dt()
    
    c.plot('All')
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 55478
# All: time
# Average scores: 0.581239296981
# Best scores:0.58795962509
# Coef:[[-0.16710676 -0.7010655  -0.16423   ]], Intercept:[ 1.27959849]
# All: ad
# Average scores: 0.554471897193
# Best scores:0.562995674117
# Coef:[[ 0.16385808 -0.37209252 -0.02320682]], Intercept:[ 0.19589087]
# %%%%%%%%%%%%%%%%%%%%%%%%

# %%
bins = {
            'All': {
                'Watching Lasting Time(s)': [1.0, 713.0, 2083.0, 5234.0, 15401.0,  270000.0],
                'Ad Ratio': [0.0, 0.040000000000000001, 0.5, 0.88, 1.0, 1.1],
                'Avg Bitrate(kbps)': [50.0, 730.39999999999998, 796.20000000000005, 1190.3, 2140.4000000000001, 2202.0],
                'Switch(per hour)': [0.0, 0.0, 0.040000000000000001, 0.12, 0.34999999999999998, 61.0],
                'Initial Time(\'o clock)': [0.0, 11.630000000000001, 14.35, 17.449999999999999, 20.530000000000001, 24]
            },

            
        }

if __name__ == '__main__':
    c = dt()
    
    c.plot('All')
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 55478
# All: time
# Average scores: 0.298947259575
# Best scores:0.303983417448
# Coef:[[-0.00125938  0.07055629  0.02288094]
#  [ 0.01599727  0.0994873   0.01394153]
#  [ 0.02304275  0.06828515  0.02702621]
#  [ 0.02355563  0.00804669 -0.01185206]
#  [-0.07349365 -0.27530563 -0.0602964 ]], Intercept:[-0.8917724  -1.0121767  -0.97156649 -0.66037515  0.66961271]
# All: ad
# Average scores: 0.273640037066
# Best scores:0.281182408075
# Coef:[[ 0.00614196  0.00056298  0.02392485]
#  [-0.10785894 -0.04261283 -0.00018309]
#  [-0.05248061 -0.00533188 -0.01637239]
#  [ 0.10696117  0.02869286 -0.02277712]
#  [ 0.04716899  0.01859231  0.01537246]], Intercept:[-0.68967627 -0.23361412 -0.28980774 -1.00036499 -0.78592753]
# %%%%%%%%%%%%%%%%%%%%%%%%

# %%
bins = {
            'All': {
                'Watching Lasting Time(s)': [1.0, 290.0, 713.0, 1291.0, 2083.0, 3306.0, 5234.0, 7890.0, 15401.0, 39330.0,  270000.0],
                'Ad Ratio': [0.0,  0.0, 0.040000000000000001, 0.42999999999999999, 0.5, 0.75, 0.88, 0.93999999999999995, 1.0, 1.0, 1.1],
                'Avg Bitrate(kbps)': [50.0, 560.70000000000005, 730.39999999999998, 780.70000000000005, 796.20000000000005, 800.0, 1190.3, 1964.5, 2140.4000000000001, 2187.1999999999998, 2202.0],
                'Switch(per hour)': [0.0, 0.0, 0.0, 0.01, 0.040000000000000001, 0.070000000000000007, 0.12, 0.20000000000000001, 0.34999999999999998, 0.69999999999999996, 61.0],
                'Initial Time(\'o clock)': [0.0, 8.4700000000000006, 11.630000000000001, 13.07, 14.35, 16.050000000000001, 17.449999999999999, 18.920000000000002, 20.530000000000001, 22.32, 24]
            },
     
            
        }

if __name__ == '__main__':
    c = dt()
    
    c.plot('All')
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: