# %%
'''
Platform:  
{ 
     iPad: 10264251 
     Android: 7512890 
     iPhone: 5377486 
     Apple TV: 368609 
     iPod: 243399 
     Mac: 21074 
     Windows: 423 
     None: 133 
}

[1, 2, 3, 4, 5, 6, 7, 8],
['Apple TV', 'Mac', 'Windows', 'iPad', 'Android', 'iPhone', 'iPod', 'Unknown']
'''
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import cross_val_score
from sklearn.datasets import load_svmlight_file
from sklearn.cross_validation import train_test_split, KFold


from sklearn import svm

platform = { 
                   'All': -1,
                   'Apple TV': 1, 
                   'Mac': 2, 
                   'Windows': 3, 
                   'iPad': 4, 
                   'Android': 5, 
                   'iPhone': 6, 
                   'iPod' : 7, 
                   'None' :8, 
                }

metric_list = ['Watching Lasting Time(s)',
               'Ad Ratio',
               'Avg Bitrate(kbps)',
               'Switch(per hour)',
               'Initial Time(\'o clock)']

metric = {
                  'Watching Lasting Time(s)': 0,
                  'Ad Ratio': 1,
                  'Avg Bitrate(kbps)': 2,
                  'Switch(per hour)': 3,
                  'Initial Time(\'o clock)': 5
              }
train = None

bins = {
            'Watching Lasting Time(s)': [0, 130500, 261000],
            'Ad Ratio': [0, 0.5, 1.1],
            'Avg Bitrate(kbps)': [0, 1250, 2500],
            'Switch(per hour)': [0, 30, 61],
            'Initial Time(\'o clock)': [0, 12, 24]
}
        

class dt:

    def __init__(self):
        global train
        
        X_train, y_train = load_svmlight_file('./data/time_train4')
        X_train, y_train2 = load_svmlight_file('./data/ad_train4')
        X_train = X_train.toarray()
        train = np.column_stack((y_train, y_train2, X_train))



    def train_and_test(self, feature, label, n=10, test_size=0.1):
        scores = []
        max_score = -1
        max_clf = None
        
        kf = KFold(n=label.shape[0], n_folds=5)
        for train_index, test_index in kf:
            feature_train, feature_test = feature[train_index], feature[test_index]
            label_train, label_test = label[train_index], label[test_index]

            clf = svm.LinearSVC()
            clf = clf.fit(feature_train, label_train)
            score = clf.score(feature_test, label_test)
            if score > max_score:
                max_score = score
                max_clf = clf
            scores.append(score)
        print "scores: " + str(scores)
        return max_score, max_clf
            
    def plot(self, p):
        global platform
        global metric
        global train
        
        if platform[p] == platform['All']:
            mat = np.zeros((train[:,:].shape[0],5))
        else:
            mat = np.zeros((train[train[:,4]==platform[p],:].shape[0],5))
        for idx, m in enumerate(metric_list):

            if platform[p] == platform['All']:
                mat[:, idx] = numpy.digitize(train[:, metric[m]], bins[m])
            else:
                mat[:, idx] = numpy.digitize(train[train[:,4]==platform[p], metric[m]], bins[m])
            
            #print "%f\t%f" %(np.amax(train[train[:,4]==platform[p], metric[m]]), np.amax(mat[:, idx]))
            
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        print 'Sample size: ' + str(mat.shape[0])
        
        time_train = mat[:, 0]
        ad_train = mat[:, 1]
        features = mat[:, 2:5]
        
        print p + ": time"
        time_score, time_clf = self.train_and_test(features, time_train)
        print "Best scores:" + str(time_score)
        print "Coef:" + str(time_clf.coef_) + ", Intercept:" + str(time_clf.intercept_)
        
        print p + ": ad"
        ad_score, ad_clf = self.train_and_test(features, ad_train)
        print "Best scores:" + str(ad_score)
        print "Coef:" + str(ad_clf.coef_) + ", Intercept:" + str(ad_clf.intercept_)
        

        
        print "%%%%%%%%%%%%%%%%%%%%%%%%"
        
        

if __name__ == '__main__':

    c = dt()
    
    c.plot('All')
    
    c.plot('iPad')
    
    c.plot('Android')
    
    c.plot('iPhone')
    
    c.plot('Apple TV')
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 55478
# All: time
# scores: [0.96304974765681328, 0.96205839942321558, 0.96241888968997835, 0.96566020730058588, 0.96313654799459214]
# Best scores:0.965660207301
# Coef:[[-0.04478389 -0.337181   -0.10581158]], Intercept:[-0.337181]
# All: ad
# scores: [0.64717015140591205, 0.64726027397260277, 0.65555155010814703, 0.64344299233889135, 0.64840018026137902]
# Best scores:0.655551550108
# Coef:[[ 0.28002477 -1.08694827  0.04805285]], Intercept:[ 0.90705609]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 23415
# iPad: time
# scores: [0.97992739696775566, 0.97651078368567157, 0.9762972453555413, 0.98270339525944905, 0.97907324364723469]
# Best scores:0.982703395259
# Coef:[[-0.00903294 -0.40634774 -0.06991465]], Intercept:[-0.40634774]
# iPad: ad
# scores: [0.74653000213538334, 0.73563954729874015, 0.75165492205850948, 0.73563954729874015, 0.74225923553277817]
# Best scores:0.751654922059
# Coef:[[ 0.16540242 -0.86168613  0.00327537]], Intercept:[ 1.02461328]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 13760
# Android: time
# scores: [0.91097383720930236, 0.91424418604651159, 0.91715116279069764, 0.92405523255813948, 0.91061046511627908]
# Best scores:0.924055232558
# Coef:[[-0.02748678 -0.26548834 -0.15471254]], Intercept:[-0.26548834]
# Android: ad
# scores: [0.66860465116279066, 0.67151162790697672, 0.65770348837209303, 0.67005813953488369, 0.64861918604651159]
# Best scores:0.671511627907
# Coef:[[ 0.00072815 -0.51537124 -0.07864572]], Intercept:[ 0.32784024]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 17102
# iPhone: time
# scores: [0.97895352236188249, 0.97866121017246421, 0.97894736842105268, 0.97748538011695907, 0.98245614035087714]
# Best scores:0.982456140351
# Coef:[[-0.26771638 -0.26771638 -0.08532273]], Intercept:[-0.26771638]
# iPhone: ad
# scores: [0.76848874598070738, 0.78515054077755042, 0.79005847953216379, 0.7792397660818714, 0.77192982456140347]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-eb1e6d5edb05> in <module>()
#     146     c.plot('iPhone')
#     147
# --> 148     c.plot('Apple TV')
#
# <ipython-input-3-eb1e6d5edb05> in plot(self, p)
#     124
#     125         print p + ": ad"
# --> 126         ad_score, ad_clf = self.train_and_test(features, ad_train)
#     127         print "Best scores:" + str(ad_score)
#     128         print "Coef:" + str(ad_clf.coef_) + ", Intercept:" + str(ad_clf.intercept_)
#
# <ipython-input-3-eb1e6d5edb05> in train_and_test(self, feature, label, n, test_size)
#      83
#      84             clf = svm.LinearSVC()
# ---> 85             clf = clf.fit(feature_train, label_train)
#      86             score = clf.score(feature_test, label_test)
#      87             if score > max_score:
#
# /usr/local/lib/python2.7/dist-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     671         y_ind = self._enc.fit_transform(y)
#     672         if len(self.classes_) < 2:
# --> 673             raise ValueError("The number of classes has to be greater than"
#     674                              " one.")
#     675
#
# ValueError: The number of classes has to be greater than one.
# Best scores:0.790058479532
# Coef:[[ 0.85647107 -1.21294008  0.02892205]], Intercept:[ 0.85647107]
# %%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%
# Sample size: 348
# Apple TV: time
# scores: [0.98571428571428577, 0.97142857142857142, 0.97142857142857142, 0.98550724637681164, 0.95652173913043481]
# Best scores:0.985714285714
# Coef:[[-0.0639075  -0.38702091 -0.03505372]], Intercept:[-0.38702091]
# Apple TV: ad
