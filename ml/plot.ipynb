# %%
'''time = {
        'bayes':
                {
                    'All':54,
                    'iPad':60,
                    'iPhone':59,
                    'Android':57,
                    'Apple TV':62
                },
         'lr':
                 {
                    'All':60,
                    'iPad':64,
                    'iPhone':62,
                    'Android':57,
                    'Apple TV':63
                },
         'decision tree':
                 {
                    'All':96,
                    'iPad':97,
                    'iPhone':97,
                    'Android':91,
                    'Apple TV':98
                }
         }'''

time = [54, 60, 59, 57, 62, 
        60, 64, 62, 57, 63,
        62, 63, 61, 55, 62,
        96, 97, 97, 91, 98]

import numpy as np
import matplotlib.pyplot as plt

total = time

'''for cls in time.keys():
    for device in time[cls].keys():
        total.append(time[cls][device])
'''        
ind = np.arange(len(total))

width = 0.5

plt.figure(num=1, figsize=(8, 6))
c = ['k', 'r', 'b', 'g', 'y']
plots = []

x = np.arange(len(total))


x[5:] = x[5:] + 1
x[10:] = x[10:] + 1
x[15:] = x[15:] + 1

for i in ind:

    p, = plt.bar(x[i], total[i], width, color=c[i%5])
    plots.append(p)

indd = (2+width/2.,8+width/2.,14+width/2.,20+width/2.)

plt.xticks(indd, ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree'] ) 

plt.legend(plots[0:5], ['All', 'iPad', 'iPhone', 'Android', 'Apple TV'], loc=2)
plt.ylabel('Precision %')
plt.xlabel('Classifier')
plt.title('Predict 2-bin watching time\n using various classifiers with or without external factors')
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure/predict_time.eps', format='eps')

# %%
'''time = {
        'bayes':
                {
                    'All':54,
                    'iPad':60,
                    'iPhone':59,
                    'Android':57,
                    'Apple TV':62
                },
         'lr':
                 {
                    'All':60,
                    'iPad':64,
                    'iPhone':62,
                    'Android':57,
                    'Apple TV':63
                },
         'decision tree':
                 {
                    'All':96,
                    'iPad':97,
                    'iPhone':97,
                    'Android':91,
                    'Apple TV':98
                }
         }'''

ad = [52, 53, 53, 56, 
        51, 57, 56, 55,
        64, 56, 56, 55,
        65, 75, 79, 67]

import numpy as np
import matplotlib.pyplot as plt

total = ad

'''for cls in time.keys():
    for device in time[cls].keys():
        total.append(time[cls][device])
'''        
ind = np.arange(len(total))

width = 0.5

plt.figure(num=2, figsize=(8, 6))
c = ['k', 'r', 'b', 'g']
plots = []

x = np.arange(len(total))


x[4:] = x[4:] + 1
x[8:] = x[8:] + 1
x[12:] = x[12:] + 1

for i in ind:

    p, = plt.bar(x[i], total[i], width, color=c[i%4])
    plots.append(p)

indd = (1.5+width/2.,6.5+width/2.,11.5+width/2.,16.5+width/2.)

plt.xticks(indd, ['Naive Bayes', 'Logistic Regression', 'SVM', 'Decision Tree'] ) 

plt.legend(plots[0:5], ['All', 'iPad', 'iPhone', 'Android'], loc=2)
plt.ylabel('Precision %')
plt.xlabel('Classifier')
plt.title('Predict ad ratio using various classifiers\n with or without external factors')
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure/predict_ad.eps', format='eps')

# %%
import numpy as np
np.average([0.98571428571428577, 0.97142857142857142, 0.97142857142857142, 0.98550724637681164, 0.95652173913043481])
# Out:
# 0.97412008281573503

# %%
x = [2, 5, 10, 20]

time = [96, 97, 97, 91, 98,
        91, 93, 95, 85, 95,
        86, 86, 90, 79, 91,
        77, 78, 83, 71, 78]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=3, figsize=(8, 6))
c = ['k', 'r', 'b', 'g', 'y']
plots = []


for i in xrange(5):

    p, = plt.plot(x, [total[0+i], total[5+i], total[10+i], total[15+i]],  color=c[i%5], linewidth=2)
    
    pp, = plt.plot(x, [total[0+i], total[5+i], total[10+i], total[15+i]],  c[i%5]+'o')
    plots.append(p)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:5], ['All', 'iPad', 'iPhone', 'Android', 'Apple TV'], loc=4)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict watching time using different-bin decision tree\n with or without external factors')
plt.xlim(0, 22)
plt.ylim(50, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure/predict_time_bins.eps', format='eps')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = [2, 5, 10, 20]

time = [65, 75, 79, 67,
        47, 63, 62, 56,
        38, 49, 49, 29,
        31, 39, 41, 26]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=3, figsize=(8, 6))
c = ['k', 'r', 'b', 'g', 'y']
plots = []


for i in xrange(4):

    p, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  color=c[i%5], linewidth=2)
    
    pp, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  c[i%5]+'o')
    plots.append(p)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:5], ['All', 'iPad', 'iPhone', 'Android', 'Apple TV'], loc=1)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict ad ratio using different-bin decision tree\n with or without external factors')
plt.xlim(0, 22)
plt.ylim(0, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure/predict_ad_bins.eps', format='eps')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [2, 5, 10, 20]

time = [50, 58, 58, 96,
        23, 29, 30, 91,
        15, 17, 18, 86,
        8, 9, 6, 77]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=4, figsize=(8, 6))
c = ['k', 'r', 'b', 'g', 'y']
m = ['o', '^', 's', 'd', '*', '+', 'x']
plots = []


for i in xrange(4):

    p, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  color=c[i%5], linewidth=2)
    
    pp, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  c[i%5]+m[i%5])
    plots.append(pp)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:4], [u'Naïve Bayes', 'Logistic Regression', 'Linear SVM', 'Decision Tree'], loc=5)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict watching time using different bins\n with various classifier without external factors')
plt.xlim(0, 22)
plt.ylim(0, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure_new/predict_time_bins.eps', format='eps')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [2, 5, 10, 20]

time = [56, 55, 55, 65,
        26, 27, 27, 47,
        22, 23, 23, 38,
        19, 23, 17, 31]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=4, figsize=(8, 6))
c = ['k', 'r', 'b', 'g', 'y']
m = ['o', '^', 's', 'd', '*', '+', 'x']
plots = []


for i in xrange(4):

    p, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  color=c[i%5], linewidth=2)
    
    pp, = plt.plot(x, [total[0+i], total[4+i], total[8+i], total[12+i]],  c[i%5]+m[i%5])
    plots.append(pp)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:4], [u'Naïve Bayes', 'Logistic Regression', 'Linear SVM', 'Decision Tree'], loc=1)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict ad ratio using different bins\n with various classifier without external factors')
plt.xlim(0, 22)
plt.ylim(0, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure_new/predict_ad_bins.eps', format='eps')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [2, 5, 10, 20]

time = [96.32, 96.32, 94.81, 97.89, 97.93, 91.54, 97.41, 
        91.61, 91.61, 90.17, 93.35, 94.87, 84.42, 93.38, 
        85.89, 85.85, 84.52, 86.61, 90.34, 78.93, 85.92, 
        77.74, 77.57, 76.38, 77.61, 83.41, 70.40, 71.57, ]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=4, figsize=(8, 6))
c = ['k', 'r',  'b', 'c', 'm', 'y', 'g',]
lw = [2, 2, 2, 0.5, 0.5, 0.5, 0.5]
m = ['o', '^', 's', 'd', '*', '+', 'x']
plots = []


for i in xrange(7):

    p, = plt.plot(x, [total[0+i], total[7+i], total[14+i], total[21+i]],  color=c[i%7], linewidth=lw[i%7])
    
    pp, = plt.plot(x, [total[0+i], total[7+i], total[14+i], total[21+i]],  c[i%7]+m[i%7])
    plots.append(pp)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:7], ['Without External Factor', 'External Factor as Feature', 'Split Dataset', 'iPad', 'iPhone', 'Android', 'Apple TV', ], loc=3)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict watching time using decision tree\n with or without external factors')
plt.xlim(0, 22)
plt.ylim(60, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure_new/predict_time_bins_dt.eps', format='eps')

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [2, 5, 10, 20]

time = [64.83, 73.58, 72.42, 74.23, 77.89, 66.32, 100, 
        46.71, 60.35, 59.43, 62.32, 60.95, 55.26, 100, 
        37.75, 44.37, 43.67, 49.47, 48.69, 28.82, 100, 
        30.91, 36.28, 35.79, 38.57, 40.49, 25.80, 100, ]

import numpy as np
import matplotlib.pyplot as plt

total = time
     
ind = np.arange(len(x))


plt.figure(num=5, figsize=(8, 6))
c = ['k', 'r',  'b', 'c', 'm', 'y', 'g',]
lw = [2, 2, 2, 0.5, 0.5, 0.5, 0.5, ]
m = ['o', '^', 's', 'd', '*', '+', 'x']
plots = []


for i in xrange(7):

    p, = plt.plot(x, [total[0+i], total[7+i], total[14+i], total[21+i]],  color=c[i%7], linewidth=lw[i%7])
    
    pp, = plt.plot(x, [total[0+i], total[7+i], total[14+i], total[21+i]],  c[i%7]+m[i%7])
    plots.append(pp)



plt.xticks(x, ['2-bin', '5-bin', '10-bin', '20-bin'] ) 

plt.legend(plots[0:7], ['W/O External Factor', 'External Factor as Feature', 'Split Dataset', 'iPad', 'iPhone', 'Android', 'Apple TV', ], loc=1)
plt.ylabel('Precision %')
plt.xlabel('bins')
plt.title('Predict ad ratio using decision tree\n with or without external factors')
plt.xlim(0, 22)
#plt.ylim(60, 100)
#plt.show()
plt.savefig('/home/tangkai/DDQoE/ml/figure_new/predict_ad_bins_dt.eps', format='eps')
