# %%
import numpy, scipy.stats

data = numpy.loadtxt('/home/tangkai/data.txt')

row, col = data.shape
print row, col
print data

print scipy.stats.shapiro(data[:,0])
#print scipy.stats.shapiro(data[0:500,0])
print scipy.stats.shapiro(data[:,1])
#print scipy.stats.shapiro(data[0:500,1])
print scipy.stats.shapiro(data[:,2])

plt.figure(1)
scipy.stats.probplot(data[:,0], plot=plt);
plt.figure(2)
scipy.stats.probplot(data[0:100,0], plot=plt);

print scipy.stats.anderson(data[:,0], dist='norm')

print scipy.stats.anderson(data[:,1], dist='norm')

print scipy.stats.anderson(data[:,2], dist='norm')

#print scipy.stats.anderson(data[500:1500,0], dist='norm')

print scipy.stats.kstest(data[1:100,0], 'norm')
print scipy.stats.kstest(data[:,1], 'norm')
print scipy.stats.kstest(data[:,2], 'norm')
# Out:
# 6261 3
# [[ 115.2597656    35.203125    354.5332031 ]
#  [  94.83398438   51.33789063  264.0761719 ]
#  [ 107.9648438    71.87304688  185.2910156 ]
#  ...,
#  [  77.32617188  309.4941406    88.99804688]
#  [  53.98242188  450.3066406    30.63867188]
#  [  71.49023438  426.8378906   180.9140625 ]]
# (0.9881537556648254, 1.6473504604691752e-22)
# (0.9651041626930237, 2.1146244029148936e-36)
# (0.9813365936279297, 6.305403637733938e-28)
# (24.833153933974245, array([ 0.576,  0.656,  0.786,  0.917,  1.091]), array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# (58.319703396714431, array([ 0.576,  0.656,  0.786,  0.917,  1.091]), array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# (42.556105167810529, array([ 0.576,  0.656,  0.786,  0.917,  1.091]), array([ 15. ,  10. ,   5. ,   2.5,   1. ]))
# (1.0, 0.0)
# (0.99935572161189568, 0.0)
# (0.99839679356034472, 0.0)
