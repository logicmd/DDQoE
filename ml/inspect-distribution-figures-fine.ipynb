# %%
'''
Platform:  
{ 
     iPad: 10264251 
     Android: 7512890 
     iPhone: 5377486 
     Apple TV: 368609 
     iPod: 243399 
     Mac: 21074 
     Windows: 423 
     None: 133 
}

[1, 2, 3, 4, 5, 6, 7, 8],
['Apple TV', 'Mac', 'Windows', 'iPad', 'Android', 'iPhone', 'iPod', 'Unknown']
'''
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.datasets import load_svmlight_file

platform = { 
                   'All': -1,
                   'Apple TV': 1, 
                   'Mac': 2, 
                   'Windows': 3, 
                   'iPad': 4, 
                   'Android': 5, 
                   'iPhone': 6, 
                   'iPod' : 7, 
                   'None' :8, 
                }
        
metric = {
                  'Watching Lasting Time(s)': 0,
                  'Ad Ratio': 1,
                  'Avg Bitrate(kbps)': 2,
                  'Switch(per hour)': 3,
                  'Initial Time(\'o clock)': 5
              }
metric_list = ['Watching Lasting Time(s)',
                  'Ad Ratio',
                  'Avg Bitrate(kbps)',
                  'Switch(per hour)',
                  'Initial Time(\'o clock)']
train = None

ls = ['-', '--', '-.', ':']

class cdf:

    def __init__(self):
        global train
        
        X_train, y_train = load_svmlight_file('./data_fine/time_train')
        X_train, y_train2 = load_svmlight_file('./data_fine/ad_train')
        X_train = X_train.toarray()
        train = np.column_stack((y_train, y_train2, X_train))


    def plot(self, m, p, n, b = False, lower = 0, upper = Inf, multiple = False, name='', location = 4):
        global platform
        global metric
        global train
        
        sample = None
        mask = np.zeros((train.shape[0], ), dtype=bool)
        mask.fill(True)
        if b:
            mask = np.logical_and(train[:, metric[m]] > lower, train[:, metric[m]] < upper) 
        
        
        

        
        samples = []
        
        if multiple:
            for device in ['iPad', 'iPhone', 'Android', 'Apple TV']:
                cur_mask = np.logical_and(mask, train[:,4]==platform[device])
                samples.append(train[cur_mask, metric[m]])

        else:
            if platform[p] >= 0:
                mask = np.logical_and(mask, train[:,4]==platform[p])

            samples.append(train[mask, metric[m]])
        
        
        
        if len(samples) > 0 and samples[0].shape[0] > 0:
            plt.figure(num=n, figsize=(8, 4.8))
            
            if not multiple:
                sample = samples[0]
                ecdf = sm.distributions.ECDF(sample)
                pp, = plt.plot(ecdf.x, ecdf.y, linewidth=2, c='k')
                plt.legend([pp], ['All Devices'], loc=4)
                p = 'All Devices'
            else:
                plots = []

                for i in xrange(len(samples)):
                    sample = samples[i]
                    location = locs[i]
                    
                    if len(sample) == 0:
                        continue
                        
                    if m == 'Ad Ratio' and i==3: #Apple TV
                        sample +=1 
                        
                    ecdf = sm.distributions.ECDF(sample)
                    plot, = plt.plot(ecdf.x, ecdf.y, linewidth=2, linestyle=ls[i])

                    plots.append(plot)
                
                text = ['iPad', 'iPhone', 'Android', 'Apple TV']
                
                
                plt.legend(plots, text, loc=location)
                
                p = 'Various Devices'
            
            
            plt.xlabel(p + ": " + m)
            plt.ylabel('CDF')
            #plt.show()
            plt.savefig('/home/tangkai/DDQoE/ml/figure/fine/' + name + '.eps', format='eps')

# %%
c = cdf()
fig_num = 1
locs = [4, 2, 2, 4, 2]
name = ['all_time', 'v_time', 'all_ad', 'v_ad', 'all_bitrate', 'v_bitrate', 'all_sw', 'v_sw', 'all_init', 'v_init']
for m in metric_list:
    c.plot(m, 'All', fig_num, multiple = False, name=name[fig_num - 1])
    #print fig_num-1, locs_sub[(fig_num - 1)/2]
    c.plot(m, '', fig_num + 1, multiple = True, name=name[fig_num], location = locs[(fig_num - 1)/2])
    fig_num += 2
